# %%
import pandas as pd
data1 = pd.read_csv('loan-train.csv')

# %%
data1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data1.value_counts()
# Out:
# Loan_ID   Gender  Married  Dependents  Education     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# LP001003  Male    Yes      1           Graduate      No             4583             1508.0             128.0       360.0             1.0             Rural          N              1
# LP001005  Male    Yes      0           Graduate      Yes            3000             0.0                66.0        360.0             1.0             Urban          Y              1
# LP002347  Male    Yes      0           Graduate      No             3246             1417.0             138.0       360.0             1.0             Semiurban      Y              1
# LP002345  Male    Yes      0           Graduate      No             1025             2773.0             112.0       360.0             1.0             Rural          Y              1
# ...

# %%
import matplotlib.pyplot as plt
data1.value_counts().plot(kind='bar')
plt.show()

# %%
data1.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data1['Loan_ID'].value_counts().plot(kind='pie')
plt.show()

# %%
# Create a list of x and y coordinates for the heart shape
x = [0, 1, 2, 3, 4, 3, 2, 1, 0, -1, -2, -3, -4, -3, -2, -1]
y = [0, 1, 2, 3, 4, 5, 6, 5, 4, 3, 2, 1, 0, -1, -2, -3]

# Create a DataFrame with the x and y coordinates
df = pd.DataFrame({'x': x, 'y': y})
# Plot the heart using the 'plot' method
df.plot(x='x', y='y', kind='line', color='red', marker='o', markersize=10)

# Add a title and labels to the plot
plt.title('Heart Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Display the plot in the Jupyter Notebook
plt.show()

# %%
import numpy as np
t = np.arange(0, 2*np.pi, 0.1)
x = 16*np.sin(t)**3
y = 13*np.cos(t)-5*np.cos(2*t)-2*np.cos(3*t)-np.cos(4*t)
df = pd.DataFrame({'x': x, 'y': y})
plt.plot(df['x'], df['y'], color='red')
plt.show()

# %%
data1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
for i in data1.columns:
    print(data1[i].value_counts())
# Out:
# Loan_ID
# LP001002    1
# LP002328    1
# LP002305    1
# LP002308    1
# LP002314    1
#            ..
# LP001692    1
# LP001693    1
# LP001698    1
# LP001699    1
# LP002990    1
# Name: count, Length: 614, dtype: int64
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64
# Married
# Yes    398
# No     213
# Name: count, dtype: int64
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64
# ApplicantIncome
# 2500    9
# 4583    6
# 6000    6
# 2600    6
# 3333    5
#        ..
# 3244    1
# 4408    1
# 3917    1
# 3992    1
# 7583    1
# Name: count, Length: 505, dtype: int64
# CoapplicantIncome
# 0.0       273
# 2500.0      5
# 2083.0      5
# 1666.0      5
# 2250.0      3
#          ...
# 2791.0      1
# 1010.0      1
# 1695.0      1
# 2598.0      1
# 240.0       1
# ...

# %%
plt.scatter(data1["Education"],data1["Property_Area"])
plt.title("Scatter Plot")
plt.show()

# %%
data1.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
sem = pd.get_dummies(data1['Education'],drop_first=True,dtype=float)
sem
# Out:
#      Not Graduate
# 0             0.0
# 1             0.0
# 2             0.0
# 3             1.0
# 4             0.0
# ..            ...
# 609           0.0
# 610           0.0
# 611           0.0
# 612           0.0
# 613           0.0
#
# [614 rows x 1 columns]

# %%
plt.pie(data1['ApplicantIncome'])
plt.show()

# %%
data1.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
import plotly as py

# %%
import cufflinks as cf
from plotly.offline import iplot
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
import plotly.io as pio
import plotly.graph_objects as go
q = go.Scatter(x=data1['Loan_ID'],y=data1['Education'],mode='markers',marker={'color':'#76E533'})
layout = go.Layout(title='Loanid scatter plot',
                  xaxis=dict(title='LoanID'),
                  yaxis=dict(title='Education'),
                  hovermode='closest')
figure = go.Figure(data=q,layout=layout)
iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
q = go.Box(x=data1['Education'],y=data1['Gender'],marker={'color':'violet'})
layout=go.Layout(xaxis=dict(title='Pclass'),
                yaxis=dict(title='Age'),
                hovermode='closest')
figure = go.Figure(data=q,layout=layout)
iplot(figure)

# %%
data1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import plotly.express as px
import plotly.offline as py

# %%
py.offline.init_notebook_mode(connected=True)
import plotly.graph_objects as go
from plotly.figure_factory import create_table
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
gapminder = px.data.gapminder()

# %%
gapminder
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
gapminder.shape
# Out:
# (1704, 8)

# %%
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
gapminder.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716

# %%
gapminder.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap',
#        'iso_alpha', 'iso_num'],
#       dtype='object')

# %%
len(gapminder.columns)
# Out:
# 8

# %%
gapminder['year'].value_counts(),gapminder['year'].unique()
# Out:
# (year
#  1952    142
#  1957    142
#  1962    142
#  1967    142
#  1972    142
#  1977    142
#  1982    142
#  1987    142
#  1992    142
#  1997    142
#  2002    142
#  2007    142
#  Name: count, dtype: int64,
#  array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#         2007], dtype=int64))

# %%
gapminder.iloc[[1,4,6,23]]
# Out:
#         country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 1   Afghanistan      Asia  1957   30.332   9240934   820.853030       AFG
# 4   Afghanistan      Asia  1972   36.088  13079460   739.981106       AFG
# 6   Afghanistan      Asia  1982   39.854  12881816   978.011439       AFG
# 23      Albania    Europe  2007   76.423   3600523  5937.029526       ALB
#
#     iso_num
# 1         4
# 4         4
# 6         4
# 23        8

# %%
gapminder.isnull()
# Out:
#       country  continent   year  lifeExp    pop  gdpPercap  iso_alpha  iso_num
# 0       False      False  False    False  False      False      False    False
# 1       False      False  False    False  False      False      False    False
# 2       False      False  False    False  False      False      False    False
# 3       False      False  False    False  False      False      False    False
# 4       False      False  False    False  False      False      False    False
# ...       ...        ...    ...      ...    ...        ...        ...      ...
# 1699    False      False  False    False  False      False      False    False
# 1700    False      False  False    False  False      False      False    False
# 1701    False      False  False    False  False      False      False    False
# 1702    False      False  False    False  False      False      False    False
# 1703    False      False  False    False  False      False      False    False
#
# [1704 rows x 8 columns]

# %%
gapminder['country'].value_counts()
# Out:
# country
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: count, Length: 142, dtype: int64

# %%
for i in gapminder.columns:
    print(gapminder[i].value_counts())
    print('-------------------------------------------------------')
# Out:
# country
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: count, Length: 142, dtype: int64
# -------------------------------------------------------
# continent
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: count, dtype: int64
# -------------------------------------------------------
# year
# 1952    142
# 1957    142
# 1962    142
# 1967    142
# 1972    142
# 1977    142
# 1982    142
# 1987    142
# 1992    142
# 1997    142
# 2002    142
# 2007    142
# Name: count, dtype: int64
# -------------------------------------------------------
# lifeExp
# 69.390    4
# 66.800    3
# 78.770    3
# 70.750    3
# 76.420    3
#          ..
# 55.861    1
# 52.644    1
# 49.265    1
# 45.580    1
# ...

# %%
can_data = px.data.gapminder().query("country=='Canada'")

# %%
fig = px.bar(can_data,x='year',y='pop',height=400)
fig.show()

# %%
can_data = px.data.gapminder().query("country=='India'")
fig = px.bar(can_data,x='year',y='pop',height=400)
fig.show()

# %%
gapminder2007= gapminder.query("year==2007")
fig=px.scatter(gapminder2007,x='gdpPercap',y='lifeExp',color='continent',size='pop',size_max=50,hover_name='country',facet_col='continent')
fig.show()

# %%
yearg = px.data.gapminder().query('year>=1992 & year<=2002 ')

# %%
fig=px.scatter(yearg,x='gdpPercap',y='lifeExp',color='continent',size='pop',size_max=40,
               hover_name='country',log_x=True,animation_frame='year',
               animation_group='country',range_x=[25,10000],range_y=[25,90],
              labels=dict(pop='Population',gdpPercap='GDP Per Capita',lifeExp='Life Expectancy'))
fig.show()
